# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("./diabetes.csv")
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
dataset.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
dataset = dataset.drop_duplicates()

# %%
dataset["Glucose"] = dataset["Glucose"].replace(0,dataset["Glucose"].mean())
dataset["BloodPressure"] = dataset["BloodPressure"].replace(0,dataset["BloodPressure"].mean())
dataset["SkinThickness"] = dataset["SkinThickness"].replace(0,dataset["SkinThickness"].mean())
dataset["Insulin"] = dataset["Insulin"].replace(0,dataset["Insulin"].mean())
dataset["BMI"] = dataset["BMI"].replace(0,dataset["BMI"].mean())

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479  118.660163
# std       3.369578   30.436016      12.115932       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
print("----------------Mean---------------\n",dataset.mean(),"\n---------------------------------------")
print("----------------Median---------------\n",dataset.median(),"\n---------------------------------------")
print("----------------Mode---------------\n",dataset.mode(),"\n---------------------------------------")
print("----------------Standard deviation---------------\n",dataset.std(),"\n---------------------------------------")
# Out:
# ----------------Mean---------------
#  Pregnancies                   3.845052
# Glucose                     121.681605
# BloodPressure                72.254807
# SkinThickness                26.606479
# Insulin                     118.660163
# BMI                          32.450805
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64
# ---------------------------------------
# ----------------Median---------------
#  Pregnancies                   3.000000
# Glucose                     117.000000
# BloodPressure                72.000000
# SkinThickness                23.000000
# Insulin                      79.799479
# BMI                          32.000000
# DiabetesPedigreeFunction      0.372500
# Age                          29.000000
# Outcome                       0.000000
# dtype: float64
# ---------------------------------------
# ----------------Mode---------------
#     Pregnancies  Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# 0          1.0     99.0           70.0      20.536458  79.799479  32.0
# 1          NaN    100.0            NaN            NaN        NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN
# ---------------------------------------
# ----------------Standard deviation---------------
#  Pregnancies                  3.369578
# Glucose                     30.436016
# BloodPressure               12.115932
# SkinThickness                9.631241
# Insulin                     93.080358
# BMI                          6.875374
# DiabetesPedigreeFunction     0.331329
# Age                         11.760232
# Outcome                      0.476951
# dtype: float64
# ---------------------------------------

# %%
dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  110.705367      70.810008      25.373135  106.457354
# 1           4.865672  142.159661      74.950326      28.907494  141.426597
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.880066                  0.429734  31.190000
# 1        35.381288                  0.550500  37.067164

# %%
X = dataset.drop("Outcome",axis=1)
Y = dataset["Outcome"]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()
knn = KNeighborsClassifier()
svm = svm.SVC()
nb = GaussianNB()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()

# %%
def logistic_regression_model():
    lr.fit(x_train,y_train)
    lr_predict = lr.predict(x_test)
    
    print("Training accuracy of logistic regression ",lr.score(x_train,y_train))
    print("Testing accuracy of logistic regression ",lr.score(x_test,y_test))
    print("Prediction accuracy of logistic regression ",accuracy_score(y_test,lr_predict))
    print()

# %%
def knn_classifier_model():
    knn.fit(x_train,y_train)
    knn_predict = knn.predict(x_test)
    
    print("Training accuracy of KNN ",knn.score(x_train,y_train))
    print("Testing accuracy of KNN ",knn.score(x_test,y_test))
    print("Prediction accuracy of KNN ",accuracy_score(y_test,knn_predict))
    print()

# %%
def svm_model():
    svm.fit(x_train,y_train)
    svm_predict = svm.predict(x_test)
    
    print("Training accuracy of SVM ",svm.score(x_train,y_train))
    print("Testing accuracy of SVM ",svm.score(x_test,y_test))
    print("Prediction accuracy of SVM ",accuracy_score(y_test,svm_predict))
    print()

# %%
def naive_bayes_model():
    nb.fit(x_train,y_train)
    nb_predict = nb.predict(x_test)
    
    print("Training accuracy of naive bayes ",nb.score(x_train,y_train))
    print("Testing accuracy of naive bayes ",nb.score(x_test,y_test))
    print("Prediction accuracy of naive bayes ",accuracy_score(y_test,nb_predict))
    print()

# %%
def decision_tree_model():
    dt.fit(x_train,y_train)
    dt_predict = dt.predict(x_test)
    
    print("Training accuracy of decision tree ",dt.score(x_train,y_train))
    print("Testing accuracy of decision tree",dt.score(x_test,y_test))
    print("Prediction accuracy of decision tree ",accuracy_score(y_test,dt_predict))
    print()

# %%
def random_forest_model():
    rf.fit(x_train,y_train)
    rf_predict = rf.predict(x_test)
    
    print("Training accuracy of random forest ",rf.score(x_train,y_train))
    print("Testing accuracy of random forest ",rf.score(x_test,y_test))
    print("Prediction accuracy of random forest ",accuracy_score(y_test,rf_predict))

# %%
test_size=[0.2,0.3,0.4]
for i in test_size:
    x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=i,random_state=7)
    
    print(("Accuracy score For test size = "+str(i*100)+"%").center(60))
    print("------------------------------------------------------------")
    logistic_regression_model()
    knn_classifier_model()
    svm_model()
    naive_bayes_model()
    decision_tree_model()
    random_forest_model()
    print("------------------------------------------------------------")
    print()
# Out:
#             Accuracy score For test size = 20.0%
# ------------------------------------------------------------
# Training accuracy of logistic regression  0.7752442996742671
# Testing accuracy of logistic regression  0.7727272727272727
# Prediction accuracy of logistic regression  0.7727272727272727
#
# Training accuracy of KNN  0.8110749185667753
# Testing accuracy of KNN  0.7467532467532467
# Prediction accuracy of KNN  0.7467532467532467
#
# Training accuracy of SVM  0.8192182410423453
# Testing accuracy of SVM  0.8311688311688312
# Prediction accuracy of SVM  0.8311688311688312
#
# Training accuracy of naive bayes  0.742671009771987
# Testing accuracy of naive bayes  0.7402597402597403
# Prediction accuracy of naive bayes  0.7402597402597403
#
# Training accuracy of decision tree  1.0
# Testing accuracy of decision tree 0.8116883116883117
# Prediction accuracy of decision tree  0.8116883116883117
#
# Training accuracy of random forest  1.0
# Testing accuracy of random forest  0.8181818181818182
# Prediction accuracy of random forest  0.8181818181818182
# ------------------------------------------------------------
#
#             Accuracy score For test size = 30.0%
# ------------------------------------------------------------
# Training accuracy of logistic regression  0.7802607076350093
# Testing accuracy of logistic regression  0.7662337662337663
# Prediction accuracy of logistic regression  0.7662337662337663
#
# Training accuracy of KNN  0.8286778398510242
# Testing accuracy of KNN  0.7575757575757576
# Prediction accuracy of KNN  0.7575757575757576
#
# Training accuracy of SVM  0.8305400372439479
# Testing accuracy of SVM  0.7965367965367965
# Prediction accuracy of SVM  0.7965367965367965
#
# Training accuracy of naive bayes  0.7486033519553073
# Testing accuracy of naive bayes  0.7272727272727273
# Prediction accuracy of naive bayes  0.7272727272727273
#
# Training accuracy of decision tree  1.0
# Testing accuracy of decision tree 0.7186147186147186
# Prediction accuracy of decision tree  0.7186147186147186
#
# Training accuracy of random forest  1.0
# Testing accuracy of random forest  0.7662337662337663
# Prediction accuracy of random forest  0.7662337662337663
# ------------------------------------------------------------
#
#             Accuracy score For test size = 40.0%
# ------------------------------------------------------------
# Training accuracy of logistic regression  0.7804347826086957
# Testing accuracy of logistic regression  0.7662337662337663
# Prediction accuracy of logistic regression  0.7662337662337663
#
# Training accuracy of KNN  0.8195652173913044
# Testing accuracy of KNN  0.7467532467532467
# Prediction accuracy of KNN  0.7467532467532467
#
# Training accuracy of SVM  0.8282608695652174
# Testing accuracy of SVM  0.7727272727272727
# Prediction accuracy of SVM  0.7727272727272727
#
# Training accuracy of naive bayes  0.7543478260869565
# Testing accuracy of naive bayes  0.7402597402597403
# Prediction accuracy of naive bayes  0.7402597402597403
#
# Training accuracy of decision tree  1.0
# Testing accuracy of decision tree 0.7012987012987013
# Prediction accuracy of decision tree  0.7012987012987013
#
# Training accuracy of random forest  1.0
# Testing accuracy of random forest  0.7824675324675324
# Prediction accuracy of random forest  0.7824675324675324
# ------------------------------------------------------------

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=7)
svm.fit(x_train,y_train)
svm_predict = svm.predict(x_test)
    
print("Training accuracy of SVM ",svm.score(x_train,y_train))
print("Testing accuracy of SVM ",svm.score(x_test,y_test))
print("Prediction accuracy of SVM ",accuracy_score(y_test,svm_predict))
# Out:
# Training accuracy of SVM  0.8192182410423453
# Testing accuracy of SVM  0.8311688311688312
# Prediction accuracy of SVM  0.8311688311688312

# %%
test_input = [[0, 140, 57, 28, 163, 37, 0.55, 35]]
std_input = scaler.transform(test_input)

print(svm.predict(std_input))
# Out:
# [1]

# %%
import pickle
pickle.dump(svm,open('diabetes_svm_model.pkl','wb'))
